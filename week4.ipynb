# %%
import pandas as pd
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.iloc[0:5,0:3] #iloc is exclusive
# Out:
#    sepal.length  sepal.width  petal.length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %%
iris.loc[[0,1,2,5],"sepal.length":"petal.width"] #loc in inclusive
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 5           5.4          3.9           1.7          0.4

# %%
# iris.drop(columns=["petal.length","petal.width"],inplace =True)

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
def half(s):
    return s*0.50

# %%
iris[["sepal.length","variety"]]
# Out:
#      sepal.length    variety
# 0             5.1     Setosa
# 1             4.9     Setosa
# 2             4.7     Setosa
# 3             4.6     Setosa
# 4             5.0     Setosa
# ..            ...        ...
# 145           6.7  Virginica
# 146           6.3  Virginica
# 147           6.5  Virginica
# 148           6.2  Virginica
# 149           5.9  Virginica
#
# [150 rows x 2 columns]

# %%
iris.sort_values(by = "sepal.length")
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 13            4.3          3.0           1.1          0.1     Setosa
# 42            4.4          3.2           1.3          0.2     Setosa
# 38            4.4          3.0           1.3          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 41            4.5          2.3           1.3          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  Virginica
# 118           7.7          2.6           6.9          2.3  Virginica
# 117           7.7          3.8           6.7          2.2  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# 131           7.9          3.8           6.4          2.0  Virginica
#
# [150 rows x 5 columns]

# %%
iris["sepal.length"].value_counts()
# Out:
# sepal.length
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
iris.sort_values(by=["variety","petal.length"],ascending=[False,True])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 106           4.9          2.5           4.5          1.7  Virginica
# 126           6.2          2.8           4.8          1.8  Virginica
# 138           6.0          3.0           4.8          1.8  Virginica
# 121           5.6          2.8           4.9          2.0  Virginica
# 123           6.3          2.7           4.9          1.8  Virginica
# ..            ...          ...           ...          ...        ...
# 18            5.7          3.8           1.7          0.3     Setosa
# 20            5.4          3.4           1.7          0.2     Setosa
# 23            5.1          3.3           1.7          0.5     Setosa
# 24            4.8          3.4           1.9          0.2     Setosa
# 44            5.1          3.8           1.9          0.4     Setosa
#
# [150 rows x 5 columns]

# %%
iris.nsmallest(1,columns='petal.length')
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 22           4.6          3.6           1.0          0.2  Setosa

# %%
iris.rename(columns={"petal.length":"PETAL.LENGTH"})
# Out:
#      sepal.length  sepal.width  PETAL.LENGTH  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
